# %%
import cv2 , numpy as np , matplotlib.pyplot as plt

# %%
sample_img = cv2.imread("C:/Users/photo1697438595.jpeg")
img=cv2.resize(img,(255,255))

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
_, thresh = cv2.threshold(gray, np.mean(gray), 255, cv2.THRESH_BINARY)

# %%
plt.axis("off")
plt.imshow(thresh)

# %%
edge = cv2.dilate(cv2.Canny(thresh,0,255), None)
plt.imshow(edge)

# %%
contours, _ = cv2.findContours(edge, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
contours = sorted(contours, key=cv2.contourArea, reverse=True)

# %%
if contours:
    cnt = contours[0]
    mask = np.zeros((256, 256), np.uint8)
    masked = cv2.drawContours(mask, [cnt], -1, 1, thickness=cv2.FILLED)
    plt.axis('off')
    plt.imshow(masked, cmap='gray')
    plt.show()
else:
    print("No contour found.")

# %%
Dst = cv2.bitwise_and(img, mask=mask)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Untitled-2.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X16sdW50aXRsZWQ%3D?line=0'>1</a> Dst = cv2.bitwise_and(img, mask=mask)
#
# error: OpenCV(4.8.1) :-1: error: (-5:Bad argument) in function 'bitwise_and'
# > Overload resolution failed:
# >  - bitwise_and() missing required argument 'src2' (pos 2)
# >  - bitwise_and() missing required argument 'src2' (pos 2)
